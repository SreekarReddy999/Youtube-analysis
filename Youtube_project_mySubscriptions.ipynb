# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
key = 'AIzaSyA-z2YNknsoQsVXOO2iZzXhhSQ8ydRLknw'
channel_id = ['UCphTF9wHwhCt-BzIq-s4V-g',
              'UCkbrlVKUj1hjQ9Bat0CvJLQ',
              'UCm7lHFkt2yB_WzL67aruVBQ',
              'UCViLvZvgdut2iJiKU33NQrQ',
              'UCBi2mrWuNuyYy4gbM6fU18Q',
              'UCkw4JCwteGrDHIsyIIKo4tQ',
              'UCP0_k4INXrwPS6HhIyYqsTg',
              'UCMDV6J2hWXet7ZCfgrXGgeg',
              'UChUrzGQzRqVxhKAV9n9nIPA',
              'UC5bu8qvD-y0eo2A6yLfvr3A',
              'UCupvZG-5ko_eiXAupbDfxWw',
              'UCiTCB-B_weEmwHk7ifNobQw',
              'UCNIFiHaLZkYASaWDdkC1njg',
              'UC_hK9fOxyy_TM8FJGXIyG8Q',
              'UCcwK4-lsxccHhd96zT3N0Mg',
              'UCbAlVnKhbGLK78GsSemQXxw',
              'UC-cANMGhn60ckHEalmMiHXw',
              'UC4rlAVgAK0SGk-yTfe48Qpw',
              'UCpqXJOEqGS-TCnazcHCo0rA',
              'UC8pYaQzbBBXg9GIOHRvTmDQ',
              'UCa10nxShhzNrCE1o2ZOPztg',
              'UCcYzLCs3zrQIBVHYA1sK2sw',
              'UCcMyVNd-RXN96XbUl152rNQ',
              'UCe_Fx4EZAgKjDz0aQ_Y7hSA',
              'UCuWcjpKbIDAbZfHoru1toFg',
              'UC65afEgL62PGFWXY7n6CUbA',
              'UC295-Dw_tDNtZXFeAPAW6Aw',
              'UCYwrS5QvBY_JbSdbINLey6Q',
              'UCkAGrHCLFmlK3H2kd6isipg',
              'UC5OrDvL9DscpcAstz7JnQGA']

# %%
youtube_channel = build('youtube', 'v3', developerKey=key)

# %%
request = youtube_channel.channels().list(
    part="snippet,contentDetails,statistics",
    id=','.join(channel_id)
)

response = request.execute()
response

# %%
final_list = []

for item in response.get('items', []):
    statistics = item.get('statistics', {})
    snippet = item.get('snippet', {})
    title = snippet.get('title', '')
    final_list_ = {'Title':title, **statistics}
    final_list.append(final_list_)

for i in final_list:
  print(i)
# Out:
# {'Title': 'Trap Nation', 'viewCount': '14074825341', 'subscriberCount': '30400000', 'hiddenSubscriberCount': False, 'videoCount': '2732'}
# {'Title': 'BMW', 'viewCount': '227982637', 'subscriberCount': '1400000', 'hiddenSubscriberCount': False, 'videoCount': '773'}
# {'Title': 'Texas Plinking', 'viewCount': '142660464', 'subscriberCount': '1050000', 'hiddenSubscriberCount': False, 'videoCount': '322'}
# {'Title': 'Top Fives', 'viewCount': '1137706981', 'subscriberCount': '2750000', 'hiddenSubscriberCount': False, 'videoCount': '1650'}
# {'Title': 'MotoGP', 'viewCount': '2260092344', 'subscriberCount': '5770000', 'hiddenSubscriberCount': False, 'videoCount': '8173'}
# {'Title': 'Mr Bean', 'viewCount': '10652510664', 'subscriberCount': '32100000', 'hiddenSubscriberCount': False, 'videoCount': '3108'}
# {'Title': 'theRadBrad', 'viewCount': '6064568492', 'subscriberCount': '13300000', 'hiddenSubscriberCount': False, 'videoCount': '8212'}
# ...

# %%
data_youtube = pd.DataFrame(final_list)
data_youtube
# Out:
#                    Title    viewCount subscriberCount  hiddenSubscriberCount  \
# 0            Trap Nation  14074825341        30400000                  False
# 1                    BMW    227982637         1400000                  False
# 2         Texas Plinking    142660464         1050000                  False
# 3              Top Fives   1137706981         2750000                  False
# 4                 MotoGP   2260092344         5770000                  False
# 5                Mr Bean  10652510664        32100000                  False
# 6             theRadBrad   6064568492        13300000                  False
# 7            BRIGHT SIDE  10745088808        44500000                  False
# 8                What If   1410793441         7460000                  False
# 9      GTA Series Videos   2194147129         3670000                  False
# 10  USA Military Channel    573113421         1610000                  False
# ...

# %%
data_youtube.to_csv('my_youtube_30.csv')
